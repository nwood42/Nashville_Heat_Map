# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from tabulate import tabulate

# %%
cd_2022 = pd.read_csv('C:/Data/Nash_Census_2022/nhgis0018_csv/nhgis0018_csv/nhgis0018_ds249_20205_tract.csv')

# %%
cd_2022.shape
# Out:
# (85395, 61)

# %%
tn_cd_2022 = cd_2022[(cd_2022['STATE'] == 'Tennessee')]

# %%
tn_cd_2022.shape
# Out:
# (1701, 61)

# %%
tn_cd_2022.head()
# Out:
#               GISJOIN       YEAR STUSAB  REGIONA  DIVISIONA      STATE  \
# 68678  G4700010020100  2016-2020     TN      NaN        NaN  Tennessee
# 68679  G4700010020201  2016-2020     TN      NaN        NaN  Tennessee
# 68680  G4700010020202  2016-2020     TN      NaN        NaN  Tennessee
# 68681  G4700010020300  2016-2020     TN      NaN        NaN  Tennessee
# 68682  G4700010020400  2016-2020     TN      NaN        NaN  Tennessee
#
#        STATEA           COUNTY  COUNTYA  CTY_SUBA  ...  AMZME008  \
# 68678      47  Anderson County        1       NaN  ...      1620
# 68679      47  Anderson County        1       NaN  ...      3338
# 68680      47  Anderson County        1       NaN  ...      2546
# 68681      47  Anderson County        1       NaN  ...      2602
# 68682      47  Anderson County        1       NaN  ...      2463
#
#                                                 NAME_M  AMZMM001  AMZMM002  \
# ...

# %%
nash_cd_2022 = tn_cd_2022[(tn_cd_2022['COUNTY'] == 'Davidson County')]

# %%
nash_cd_2022.shape
# Out:
# (174, 61)

# %%
nash_poverty_cd_2022 = nash_cd_2022[['GISJOIN', 'YEAR', 'STATE', 'COUNTY', 'TRACTA', 'GEOID', 'AMZME001', 'AMZME002', 'AMZME003']]

# %%
nash_poverty_cd_2022.head()
# Out:
#               GISJOIN       YEAR      STATE           COUNTY  TRACTA  \
# 68890  G4700370010103  2016-2020  Tennessee  Davidson County   10103
# 68891  G4700370010104  2016-2020  Tennessee  Davidson County   10104
# 68892  G4700370010105  2016-2020  Tennessee  Davidson County   10105
# 68893  G4700370010106  2016-2020  Tennessee  Davidson County   10106
# 68894  G4700370010201  2016-2020  Tennessee  Davidson County   10201
#
#                     GEOID  AMZME001  AMZME002  AMZME003
# 68890  14000US47037010103      2376        50       116
# 68891  14000US47037010104      3002        26       219
# 68892  14000US47037010105      4839       234       120
# 68893  14000US47037010106      2812       171       268
# 68894  14000US47037010201      4283       287       340

# %%
nash_poverty_cd_2022.rename(columns = {'AMZME001' : 'TotalHouseholds', 'AMZME002' : 'UnderHalfPL', 'AMZME003' : 'UnderPL'}, inplace = True)
# Out:
# C:\Users\there\AppData\Local\Temp\ipykernel_30184\1129559986.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nash_poverty_cd_2022.rename(columns = {'AMZME001' : 'TotalHouseholds', 'AMZME002' : 'UnderHalfPL', 'AMZME003' : 'UnderPL'}, inplace = True)

# %%
nash_poverty_cd_2022.head()
# Out:
#               GISJOIN       YEAR      STATE           COUNTY  TRACTA  \
# 68890  G4700370010103  2016-2020  Tennessee  Davidson County   10103
# 68891  G4700370010104  2016-2020  Tennessee  Davidson County   10104
# 68892  G4700370010105  2016-2020  Tennessee  Davidson County   10105
# 68893  G4700370010106  2016-2020  Tennessee  Davidson County   10106
# 68894  G4700370010201  2016-2020  Tennessee  Davidson County   10201
#
#                     GEOID  TotalHouseholds  UnderHalfPL  UnderPL
# 68890  14000US47037010103             2376           50      116
# 68891  14000US47037010104             3002           26      219
# 68892  14000US47037010105             4839          234      120
# 68893  14000US47037010106             2812          171      268
# 68894  14000US47037010201             4283          287      340

# %%
nash_poverty_cd_2022['PercentUnderPL'] = ((nash_poverty_cd_2022.UnderHalfPL + nash_poverty_cd_2022.UnderPL) /
nash_poverty_cd_2022.TotalHouseholds) * 100
# Out:
# C:\Users\there\AppData\Local\Temp\ipykernel_30184\11651028.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nash_poverty_cd_2022['PercentUnderPL'] = ((nash_poverty_cd_2022.UnderHalfPL + nash_poverty_cd_2022.UnderPL) /

# %%
nash_poverty_cd_2022.head()
# Out:
#               GISJOIN       YEAR      STATE           COUNTY  TRACTA  \
# 68890  G4700370010103  2016-2020  Tennessee  Davidson County   10103
# 68891  G4700370010104  2016-2020  Tennessee  Davidson County   10104
# 68892  G4700370010105  2016-2020  Tennessee  Davidson County   10105
# 68893  G4700370010106  2016-2020  Tennessee  Davidson County   10106
# 68894  G4700370010201  2016-2020  Tennessee  Davidson County   10201
#
#                     GEOID  TotalHouseholds  UnderHalfPL  UnderPL  \
# 68890  14000US47037010103             2376           50      116
# 68891  14000US47037010104             3002           26      219
# 68892  14000US47037010105             4839          234      120
# 68893  14000US47037010106             2812          171      268
# 68894  14000US47037010201             4283          287      340
#
#        PercentUnderPL
# 68890        6.986532
# 68891        8.161226
# 68892        7.315561
# 68893       15.611664
# 68894       14.639272
